# %%
#data analytics ,descriptive statistics
import pandas as pd
import os
from scipy import stats
#print(os.getcwd())

# %%
df=pd.read_csv("/Users/Apple/Desktop/forestfires.csv")

# %%
print(df)
# Out:
#      X  Y month  day  FFMC    DMC     DC   ISI  temp  RH  wind  rain   area
# 0    7  5   mar  fri  86.2   26.2   94.3   5.1   8.2  51   6.7   0.0   0.00
# 1    7  4   oct  tue  90.6   35.4  669.1   6.7  18.0  33   0.9   0.0   0.00
# 2    7  4   oct  sat  90.6   43.7  686.9   6.7  14.6  33   1.3   0.0   0.00
# 3    8  6   mar  fri  91.7   33.3   77.5   9.0   8.3  97   4.0   0.2   0.00
# 4    8  6   mar  sun  89.3   51.3  102.2   9.6  11.4  99   1.8   0.0   0.00
# 5    8  6   aug  sun  92.3   85.3  488.0  14.7  22.2  29   5.4   0.0   0.00
# 6    8  6   aug  mon  92.3   88.9  495.6   8.5  24.1  27   3.1   0.0   0.00
# 7    8  6   aug  mon  91.5  145.4  608.2  10.7   8.0  86   2.2   0.0   0.00
# 8    8  6   sep  tue  91.0  129.5  692.6   7.0  13.1  63   5.4   0.0   0.00
# 9    7  5   sep  sat  92.5   88.0  698.6   7.1  22.8  40   4.0   0.0   0.00
# 10   7  5   sep  sat  92.5   88.0  698.6   7.1  17.8  51   7.2   0.0   0.00
# ...

# %%
sum_temp=sum(df['temp'])
#print("Average temperature in celsius")
print(sum_time)
num=len(df['temp'])
avg=sum_temp/num
print("Average temperature in celsius")
print(avg)
# Out:
# 9765.699999999999
# Average temperature in celsius
# 18.88916827852998

# %%
sorted_temp=sorted(df['temp'])
#print(sorted_time)
middle=num/2+0.5
#print(middle)
print("the median of the temperatures ")
print(sorted_temp[int(middle)])
# Out:
# the median of the amount of rain
# 19.3

# %%
df['temp'].mode()
# Out:
# 0    17.4
# 1    19.6
# dtype: float64

# %%
print(" the geometric mean of the temperature")
print(stats.gmean(df.iloc[:,8]))
# Out:
#  the harmonic mean of the temperature
# 17.735049605006243

# %%
print(" the harmonic mean of the temperature data")
print(stats.hmean(df.iloc[:,8]))
# Out:
#  the harmonic mean of the temperature data
# 16.08176161495816

# %%
forest_fire=df.describe()
print(forest_fire)
# Out:
#                 X           Y        FFMC         DMC          DC         ISI  \
# count  517.000000  517.000000  517.000000  517.000000  517.000000  517.000000
# mean     4.669246    4.299807   90.644681  110.872340  547.940039    9.021663
# std      2.313778    1.229900    5.520111   64.046482  248.066192    4.559477
# min      1.000000    2.000000   18.700000    1.100000    7.900000    0.000000
# 25%      3.000000    4.000000   90.200000   68.600000  437.700000    6.500000
# 50%      4.000000    4.000000   91.600000  108.300000  664.200000    8.400000
# 75%      7.000000    5.000000   92.900000  142.400000  713.900000   10.800000
# max      9.000000    9.000000   96.200000  291.300000  860.600000   56.100000
#
#              temp          RH        wind        rain         area
# count  517.000000  517.000000  517.000000  517.000000   517.000000
# mean    18.889168   44.288201    4.017602    0.021663    12.847292
# ...

# %%
q1=forest_fire.iloc[4]
q3=forest_fire.iloc[6]
interquartile=q3-q1
print(interquartile)
# Out:
# X         4.00
# Y         1.00
# FFMC      2.70
# DMC      73.80
# DC      276.20
# ISI       4.30
# temp      7.30
# RH       20.00
# wind      2.20
# rain      0.00
# area      6.57
# dtype: float64

# %%
import matplotlib.pyplot as plots
df.boxplot(column=["temp","RH","wind","rain"])

# %%
plots.scatter(df.area,df.temp)

# %%
month_count=df.groupby("temp").size()
month_count.plot.bar()

# %%
month_count.plot.pie()

# %%
df.hist(by='month',column=["area"],histtype = 'bar', facecolor = 'blue')
#plots.title("Histogram")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2eec0d4b4f63> in <module>()
#       1 df.hist(by='month',column=["area"],histtype = 'bar', facecolor = 'blue')
# ----> 2 plots.title("Histogram")
#
# NameError: name 'plots' is not defined
